# %%
import pickle

# Load the array from the file
with open('M_LR_NI.pkl', 'rb') as file:
    loaded_array = pickle.load(file)

# %%
loaded_array
# Out:
# [array([[-1.26238275e-04, -3.19978406e-04,  4.77401702e-04,
#           7.16053778e-05,  2.25851231e-05,  4.39332256e-05,
#           9.81421234e-05,  5.43735695e-05, -6.10811953e-05,
#          -3.59994938e-04,  4.00765264e-05,  2.40529152e-04,
#          -4.58163547e-04,  9.16239533e-05, -3.58385026e-04,
#          -1.78339895e-04,  2.29792917e-05, -2.36571521e-04,
#          -4.59367599e-04, -2.46821348e-04, -1.21578023e-04,
#          -6.08087056e-04, -4.61997953e-04, -2.67786158e-04,
#          -2.27102506e-06, -4.33094621e-07,  1.37385308e-04,
#          -2.78079089e-04, -4.14956943e-04,  3.15377630e-04,
#           7.41737598e-05,  4.96872935e-04, -2.91407286e-04,
#          -5.44343471e-05,  1.51320900e-05,  1.46375937e-04,
#           1.02333063e-04, -2.56605143e-04, -2.09332721e-04,
#           2.12807038e-04, -1.92736692e-04,  1.47708524e-04,
#          -4.96273192e-06,  4.41868840e-04,  2.53795348e-04,
#          -2.88965164e-04, -2.69688123e-05,  3.21002477e-05,
# ...
