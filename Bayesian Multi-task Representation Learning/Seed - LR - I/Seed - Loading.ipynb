# %%
import pickle

# Load the array from the file
with open('Phi_MAP_LR_I.pkl', 'rb') as file:
    loaded_array = pickle.load(file)

# %%
loaded_array
# Out:
# array([[-1.81014173e+00,  1.01234124e+00, -1.65137311e+00,
#         -8.71332249e-01, -1.38957639e+00,  1.46299498e-01,
#         -2.02673012e-01, -7.08418826e-03, -9.51339904e-02,
#          1.80987203e-01, -1.91307891e-01, -3.50518522e-01,
#         -2.04741996e-01, -7.18310162e-02, -4.93797200e-02,
#          1.77323907e-01,  4.44214222e-02,  1.03453391e-01,
#         -2.22593684e-01, -1.05123341e-01,  1.41078119e-01,
#         -1.08616741e-01,  2.01980129e-01, -1.03267771e-01,
#          2.25451665e-01,  8.40203766e-03,  5.36804346e-03,
#          1.40099441e-01,  2.50649819e-01, -1.61926213e-03,
#         -7.76843030e-02,  1.76901959e-01, -3.61201510e-02,
#         -4.43257781e-02,  3.24715147e-02,  1.54964965e-01,
#         -2.16219080e-01,  1.26365464e-01, -1.58990472e-01,
#          8.08474218e-02, -6.76881496e-02, -9.21769862e-02,
#         -3.37077478e-02,  4.97923209e-02,  9.68459277e-02,
#         -1.14256506e-01,  1.09082525e-01, -2.11159341e-01,
# ...
